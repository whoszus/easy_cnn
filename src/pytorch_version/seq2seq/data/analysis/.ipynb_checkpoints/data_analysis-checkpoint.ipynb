# %%
import os
import torch
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
def load_data_by_date(df, start, end):
    mask = (df['alm_time'] >= start) & (df['alm_time'] <= end)
    return df.loc[mask]

def load_data(start='2018-06-01', end='2018-06-02', path='ays.torch'):
    if not os.path.exists(path):
        return
    data_load = torch.load(path)['data_all']
    start_time = pd.to_datetime(start, format='%Y-%m-%d %H:%M:%S')
    end_time = pd.to_datetime(end, format='%Y-%m-%d %H:%M:%S')
    data_loaded = load_data_by_date(data_load, start_time, end_time)

    return data_loaded

# %%
data = torch.load("analysis_test.torch")['data']
data.head(5)
# Out:
#       city          dev_name dev_type    spc_type            alm_time  \
# 3376  省NOC  广州_环市西_UPortal54  UPORTAL  HW-UPORTAL 2018-06-01 00:00:00
# 3375  省NOC  广州_环市西_UPortal54  UPORTAL  HW-UPORTAL 2018-06-01 00:00:00
# 3382  省NOC   广州_马场_UPortal57  UPORTAL  HW-UPORTAL 2018-06-01 00:00:01
# 3381  省NOC   广州_马场_UPortal57  UPORTAL  HW-UPORTAL 2018-06-01 00:00:01
# 3380  省NOC  广州_环市西_UPortal58  UPORTAL  HW-UPORTAL 2018-06-01 00:00:01
#
#      clr_time  ralm_type ralm_level msg_type
# 3376      NaT  设备故障/系统软件          2        0
# 3375      NaT  设备故障/系统软件          2        2
# 3382      NaT  设备故障/系统软件          2        0
# 3381      NaT  设备故障/系统软件          2        2
# 3380      NaT  设备故障/系统软件          2        0

# %%
data_with_r = data.loc[(data.clr_time.notnull())]
data_with_r['RT'] =  data_with_r.apply(lambda x:x['clr_time']-x['alm_time'], axis=1)
data_with_r['RT'] = data_with_r['RT'].dt.total_seconds()
data_with_r.head(5)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#       city          dev_name dev_type  spc_type            alm_time  \
# 1       茂名  MM-GHB-IMS.BAC-2      BAC    HW-BAC 2018-06-01 00:00:08
# 3388    深圳       深圳_新安_IMGW2     IMGW   HW-IMGW 2018-06-01 00:00:22
# 3390  省NOC      广州_环市西_ATS58    MMTEL  HW-MMTEL 2018-06-01 00:00:40
# 3389  省NOC   广州_环市西_ATSOMU58    MMTEL  HW-MMTEL 2018-06-01 00:00:40
# 4     省NOC     广州_东莞庄_MSCe20     MSCe   AL-MSCE 2018-06-01 00:00:48
#
#                 clr_time  ralm_type ralm_level msg_type     RT
# 1    2018-06-01 00:00:08  设备故障/网元脱网          1        1    0.0
# 3388 2018-06-01 00:01:04  线路故障/光缆故障          3        1   42.0
# 3390 2018-06-01 00:14:16  设备故障/网元脱网          1        1  816.0
# 3389 2018-06-01 00:14:16  设备故障/网元脱网          1        1  816.0
# 4    2018-06-01 00:00:57  设备故障/硬件板卡          2        1    9.0
